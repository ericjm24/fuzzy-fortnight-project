#         # API.SEARCH_USER RESULTS - (100 RESULTS) CONGRESS NAME FILTERED BY KEYWORDS = CONGRESS, SENAT%, REP, DEM, HOUSE  
#         'PRyan','AmyMcGrathKY','RealOmarNavarro','RepBarbaraLee','GovPenceIN','SenDonnelly','GOPoversight','senjudiciary','MichelleGomez','AJentleson','GovMaryFallin','RepDavidEPrice','repdonnaedwards','PJK4brainhealth','PatrickMurphyPA','RepMikeRogers','RepMikeRogers','SenateAgDems','MurrayCampaign','PolisForCO','SenatorSerrano','JECDems','benraylujan','VAChair','RepJimMatheson','JohnEnsign','RepKucinich','GOPHELP','CShadegg','McCaskill4MO','RepTierney','SteveIsraelNY','BetsySweetME','RulesDemocrats','Tnprephoops','RepLynch','RichardBurr_DN','standwithraul','MikeRossUpdates','HSGAC','RepInsleeNews','MarlinStutzman','FormerSenSnowe','iSquaredAct','bradyfortexas','pattyforiowa','coffmanforco','EnriquePadron01','TomUdallPress','WelchForVT','DBrandewie','JoeCourtneyCT','Loretta2016','lynnwoolsey','DraftSB2020','BarneyFrankNews','VoteLouiseNY','vinnyspot','elaminma','bijouhills','RWTTROBMARTINEZ','TeamDingell','HarperCampaign','hillstfr','Olyindivisible','johnconyersjr','Levin4Congress','georgevoinovich','CaseyDreher','evanbayh_','GerlachforPA','BobEFilner','Mike_CA05','RepAderholtNews','AbercrombieNews','AlbioSiresNJ','repjhensarling','FChaffetz','mgorman1922','tessa_da_twit','Specter4theCure','thetrinabailey','SenDavidVitter','WaxmanHenry','HR4Congress','HowardBerman','Ruben_Hinojosa','CrapoTrump2016','CynthiaMLummis','IndivisWeirton','DennisCardoza','DaveyMU','RepPhilGingrey','RecallCarlLevin','Jim_Bunning','CongStearns','RepEngelStache','Sh_WhiteHouse','CMCMikulski','NotRolandBurris','RushHolt4Senate','BrianB4congress','SillyGooseBruce','RepJudyBiggert','MatsuiDoris','repmarcykaptur_','SaxbyChamblissM','Shelley_Berkley','repgallegly','EdTownsNY10','KelhamDouglas','rep_shuster','RepSteveKagen'    

        # 2010 Handle Search W/O REP/SEN
#         'AlanMollohan','AlbioSires','AlceeHastings','AllenBoyd','AnnKirkpatrick','BarbaraMikulski','BaronHill','BartGordon','BartStupak','BenChandler','BenjaminCardin','BenLujan','BennieThompson','BernardSanders','BettyMcCollum','Bill,Pascrell','BillDelahunt','BillPosey','BillShuster','BillYoung','BlaineLuetkemeyer','BlancheLincoln','BobbyBright','BobEtheridge','BobGoodlatte','BradEllsworth','BrianBilbray','CarolSheaPorter','CarolynKilpatrick','CarolynMaloney','CarolynMcCarthy','CarteGoodwin','CathyMcMorrisRodgers','CharlesBoustany','CharlesDent','CharlesGonzalez','CharlesRangel','CharlesSchumer','CharlesWilson','CharlieMelancon','ChristopherBond','ChristopherCarney','ChristopherCoons','ChristopherDodd','ChristopherLee','ChristopherMurphy','ChristopherSmith','ChrisVanHollen','CiroRodriguez','ClaireMcCaskill','CorrineBrown','DaleKildee','DanBoren','Daniel
olandBurris','RoscoeBartlett','RubenHinojosa','RussCarnahan','RussellFeingold','SamBrownback','SamFarr','ScottMurphy','SheilaJacksonLee','SheldonWhitehouse','ShelleyBerkley','ShelleyCapito','SolomonOrtiz','SpencerBachus','StephanieHersethSandlin','SteveAustria','SteveBuyer','SteveDriehaus','SteveKing','StevenLaTourette','StevenRothman','SueMyrick','SuzanneKosmas','TedPoe','ThaddeusMcCotter','TheodoreDeutch','ThomasCarper','ThomasPerriello','ThomasPetri','ThomasRooney','TimHolden','TimJohnson','TimMurphy','TimothyBishop','TimothyJohnson','TimothyWalz','ToddPlatts','TomCole','TomHarkin','TravisChilders','TrentFranks','VernonEhlers','VicSnyder','WalterMinnick','WilliamClay','WilliamOwens','ZacharySpace'
    
        # 2010 Not in Twitter
#         'senThomasUdall','senThomasHarkin','senThomasCoburn','senTimothyJohnson','senTammyBaldwin','senShelleyCapito','senSheldonWhitehouse','senSaxbyChambliss','senSamuelBrownback','senRolandBurris','senRogerWicker','senPaulKirk','senPattyMurray','senOlympiaSnowe','senMitchMcConnell','senMikeJohanns','senMichaelCrapo','senMelMartinez','senMaxBaucus','senMaryLandrieu','senMartinHeinrich','senMarshaBlackburn','senMarkPryor','senMarkBegich','senMariaCantwell','senLisaMurkowski','senLindseyGraham','senLamarAlexander','senKirstenGillibrand','senKentConrad','senKenSalazar','senKayHutchison','senKayHagan','senJuddGregg','senJonTester','senJohnRockefeller','senJohnnyIsakson','senJohnEnsign','senJohnCornyn','senJohnBoozman','senJosephManchin','senJosephDonnelly','senJamesWebb','senJamesDeMint','senJamesBunning','senJeffSessions','senJeffBingaman','senJeanneShaheen','senJimRisch','senJimInhofe','senHollenVan','senHerbKohl',   'senGeorgeVoinovich','senGeorgeLeMieux','senFrankLautenberg','senDebraStabenow','senClaireMcCaskill','senCharlesGrassley','senCarteGoodwin','senByronDorgan','senBlancheLincoln','senBarbaraMikulski','repZachWamp','repXavierBecerra','repWilliamClay','repVirginiaFoxx','repVictorSnyder','repVernonEhlers','repVernBuchanan','repTrentFranks','repTravisChilders','repThomasomMcClintock','repThomasLatham','repThomasCole','repToddPlatts','repTimothyMurphy','repTimothyHolden','repTadMcCotter','repTheodorePoe','repSuzanneKosmas','repSusanMyrick','repStevenKing','repStevenDriehaus','repStevenCohen','repStevenBuyer','repSteveAustria','repStenyHoyer','repSpencerBachus','repSolomonOrtiz','repSilvestreReyes','repShelleyBerkley','repScottMurphy','repSchultzWasserman','repSanfordBishop','repSandlinHerseth','repSamuelFarr','repRussellCarnahan','repRubenHinojosa','repRoscoeBartlett','repRosaDeLauro','repRodgersMcMorris','repRickBoucher',  'repRandallNeugebauer','repRalphHall','repPhillipHare','repPeterSessions','repPedroPierluisi','repPaulKanjorski','repPaulHodes','repPaulBroun','repParkerGriffith','repNydiaVelazquez','repNormanDicks','repNitaLowey','repNikiTsongas','repMicheleBachmann','repMelvinWatt','repMelissaBean','repMauriceHinchey','repMaryKilroy','repMarlinStutzman','repMarkSouder','repMarkSchauer','repMarkCritz','senMarionBerry','repMarioDiazBalart','repMadeleineBordallo','repMackBono','repLynnWestmoreland','repLynnJenkins','repLuisGutierrez','repLucilleRoybalAllard','repLouiseSlaughter','repLorettaSanchez','repLincolnDiazBalart','repLincolnDavis','repLeoBoswell','repLeeTerry','repLeeJackson','repLauraRichardson','repLarryKissell','repLamarSmith','repKurtSchrader','repKevinMcCarthy','repKendrickMeek','repKennethCalvert','repKeithEllison','repKatherineCastor','repJohnTanner','repJohnSullivan', 'repJohnSpratt','repJohnShimkus','repJohnSalazar','repJohnOlver','repJohnMurtha','repJohnLinder','repJohnGaramendi','repJohnFleming','repJohnDuncan','repJohnDingell','repJohnCulberson','repJohnBoehner','repJohnAdler','repJosephSestak','repJoanneEmerson','repJoanneBonner','repJamesMcCrery','repJamesMarshall','repJamesJordan','repJamesGerlach','senJesseJackson','repJerryMcNerney','repJerryCostello','repJerryNadler','repJeffFortenberry','repJebHensarling','repJeanSchmidt','repJasonChaffetz','repJaniceSchakowsky','repJaneHarman','repJackKingston','repJackieSpeier','repJ.Forbes','repIleanaRosLehtinen','repIkeSkelton','repHowardMcKeon','repHowardCoble','repHildaSolis','repHankJohnson','repHankCuellar','repHankBrown','repHeathShuler','repHarryTeague','repHarryMitchell','repHaroldRogers','repGreshamBarrett','repGregorioSaban','repGreggHarper','repGraceNapolitano','repGlennThompson','repGinnyBrownWaite','repGeraldConnolly','repGeorgeRadanovich','repGeorgeMiller','repGeneTaylor','repGeneGreen','repGabbyGiffords','repGKButterfield','repFrankWolf','repFrankPallone','repFrankLoBiondo','repFrankKratovil','repFortneyStark','repJamesSensenbrenner','repEricMassa','repEniFaleomavaega','repEmanuelCleaver','repEltonGallegly','repEllenTauscher','repElijahCummings','repEleanorNorton','repEdwardPerlmutter','repEdTowns','repEarlPomeroy','repEarlBlumenauer','repDuncanHunter','repDorisMatsui','repDonnaChristensen','repDonManzullo','repDocHastings','repDianeWatson','repDennyRehberg','repDennisMoore','repDennisKucinich','repDennisCardoza','repDebbieHalvorson','repDavidCamp','repDarrellIssa','repDanBoren','repDanaRohrabacher','repDaleKildee','repCorrineBrown','repCollinPeterson','repCiroRodriguez','repChetEdwards','repChelliePingree','repChakaFattah','repCarolynMcCarthy','repCarolynMaloney', 'repCarolynKilpatrick','repCarolSheaPorter','repCandiceMiller','repCWYoung','repDutchRuppersberger','repBrianBilbray','repBrettGuthrie','repBradSherman','repBradEllsworth','repRobertInglis','repRobertGoodlatte','repRobertEtheridge','repBobBright','repBlaineLuetkemeyer','repWilliamShuster','repWilliamPosey','repWilliamPascrell','repWilliamDelahunt','repBettySutton','repBettyMcCollum','repBennieThompson','repBenLujan','repBenChandler','repBartStupak','repBartGordon','repBaronHill','repBarneyFrank','repArtDavis','repTonyWeiner','repAnnKirkpatrick','repAnhCao','repAnderCrenshaw','repAllysonSchwartz','repAllenBoyd','repAlceeHastings','repAlbioSires','repAlanMollohan','repAdamPutnam'
    
        # Example:
        #'repChrisSmith','senChrisSmith','sentomrooney','@TomRooney'
] 

#----------------------------------------------------------------------------------------------------#
# CSV EXTRACT FILE
csvFile = open(file_export, 'w')
csvWriter = csv.writer(csvFile)

#----------------------------------------------------------------------------------------------------#
# HEADER ROW - CSV AND WINDOW

# CSV EXPORT HEADER ROW
csvWriter.writerow( ['user.id_str', #'user.id', 
                     'user.screen_name','user.name', 'user.description', 
                     'user.followers_count','user.friends_count', 'user.favourites_count','user.statuses_count', 'user.listed_count',
                     'user.verified', 'user.default_profile', 'user.protected',                     
                     'user.created_at', 'user.location', 'user.url'                     
                    ] )
# WINDOW HEADER ROW
print( 'user.id_str', #'user.id',
        'user.screen_name','user.name', 'user.description', 
        'user.followers_count','user.friends_count', 'user.favourites_count','user.statuses_count', 'user.listed_count',
        'user.verified', 'user.default_profile', 'user.protected',                     
        'user.created_at', 'user.location', 'user.url', '\n'                  
                     )
#----------------------------------------------------------------------------------------------------#
# DATA EXTRACT LOOP           #user.followers_count > 1000
for user_name in users_list:
    try:
        user = api.get_user( #count=count,  #-API-# 
            screen_name = user_name,
        )

        # CSV EXPORT DATA
        csvWriter.writerow([user.id_str.encode('utf-8'), #int(user.id), 
                            user.screen_name, user.name.encode('utf-8'), user.description.encode('utf-8'),
                            user.followers_count, user.friends_count, user.favourites_count, user.statuses_count, user.listed_count,      
                            user.verified, user.default_profile, user.protected,            
                            user.created_at, user.location.encode('utf-8'), user.url
                           ])  #user.withheld_in_countries,user.withheld_scope,user.derived,user.profile_banner_url, user.screen_name, user.id 
        
#----------------------------------------------------------------------------------------------------#
# PRINT RESULTS TO WINDOW (RECORD COUNT = 304)
        print(user.id_str, #user.id, 
            user.screen_name, user.name, '\n', user.description,'\n',
            user.followers_count, user.friends_count, user.favourites_count, #user.statuses_count, #user.listed_count,      
            user.verified, user.default_profile, #user.protected,            
            user.created_at, user.location, user.url, '\n' )  #user.withheld_in_countries,user.withheld_scope,user.derived,user.profile_banner_url, 

#----------------------------------------------------------------------------------------------------#
    except:
        None

#----------------------------------------------------------------------------------------------------#
csvFile.close()

print( "CSV Export Complete" )

# %%
print( "MONGO DB & TWITTER API.SEARCH (FIX DEPRACATION)")
#----------------------------------------------------------------------------------------------------#
# https://www.youtube.com/watch?v=_zxwlrYUHr4&feature=youtu.be
#----------------------------------------------------------------------------------------------------#
import pymongo
from pymongo import MongoClient
import json
import twitter
from pprint import pprint
# import tweepy
# from config import consumer_key, consumer_secret, access_token, access_token_secret
from config import consumer_key, consumer_secret, OAUTH_TOKEN, OAUTH_TOKEN_SECRET

#----------------------------------------------------------------------------------------------------#
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET, consumer_key, consumer_secret)
twitter_api=twitter.Twitter(auth=auth)

#----------------------------------------------------------------------------------------------------#
client=MongoClient()
db=client.tweet_db
tweet_collection=db.tweet_collection

# tweet_collection=db.collection("posts").countDocuments(  #DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   {}, // filters
#   {}, // options
#   function(error, result) {
#     console.log(result);
#   }
# );    #http://mongodb.github.io/node-mongodb-native/3.1/api/Collection.html#countDocuments

tweet_collection.create_index([ ("id", pymongo.ASCENDING) ], unique=True )

#---------------------------------------------------------------------------------------------------#
# # VARIABLES
count=50        #DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
q="Salesforce"

#----------------------------------------------------------------------------------------------------#
search_results=twitter_api.search.tweets( count=50, q=q )  #DeprecationWarning: count is deprecated. Use Collection.count_documents instead.  #http://mongodb.github.io/node-mongodb-native/3.1/api/Collection.html#countDocuments

statuses=search_results["statuses"]

since_id_new=statuses[-1]['id']  #sincd

for status in statuses:
    try:
        tweet_collection.insert_many(status)   #DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
    except:
        pass

#---------------------------------------------------------------------------------------------------#
tweet_cursor=tweet_collection.find()
print(tweet_cursor.count())
user_cursor=tweet_collection.distinct("user_id")
print(len(user_cursor))

for document in tweet_cursor:
    try:
        print( '-----' )
        print( 'name:-', document["user"]["name"] )
        print( 'text:-', document["name"] )
        print( 'Created Date:-', document["created_at"] )
    except:
        print("Error in Encoding")
        pass
# Out:
# MONGO DB & TWITTER API.SEARCH (FIX DEPRACATION)
# 50
# 0
# -----
# name:- Payal Mittal 💭
# Error in Encoding
# -----
# name:- Payal Mittal 💭
# Error in Encoding
# -----
# name:- Payal Mittal 💭
# Error in Encoding
# -----
# name:- Jigar Shah
# Error in Encoding
# -----
# name:- Madhur Dixit
# Error in Encoding
# -----
# name:- supplychain
# Error in Encoding
# -----
# name:- Payal Mittal 💭
# Error in Encoding
# -----
# name:- D&A TECHNOLOGIES
# Error in Encoding
# -----
# name:- Madhur Dixit
# Error in Encoding
# -----
# name:- Adrian Rosenkranz
# Error in Encoding
# -----
# name:- WiML
# Error in Encoding
# -----
# name:- Chandana Beesu
# Error in Encoding
# -----
# name:- Kishore B.T
# Error in Encoding
# -----
# name:- Yajaira “Yaya” Rivera-Fernandez, AINS
# Error in Encoding
# -----
# name:- Ethics Retweet Bot
# Error in Encoding
# -----
# name:- Matthew Pollard, CSP
# Error in Encoding
# -----
# name:- Avi Rai 🤠
# Error in Encoding
# -----
# name:- Avi Rai 🤠
# Error in Encoding
# ...

# %%
print( "API.HOME_TIMELINE (OK):" )  # http://localhost:8888/notebooks/UCD%20Project%20-%20Social.ipynb
#----------------------------------------------------------------------------------------------------#
import pandas as pd
import json 
import tweepy
import csv
from  config import consumer_key, consumer_secret, access_token, access_token_secret

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

#----------------------------------------------------------------------------------------------------#
#Make call on home timeline, print each tweets text
public_tweets = api.home_timeline()  ###
# for tweet in public_tweets:
#     print( tweet.text )        # My Timeline
#     print( public_tweets[0] )  # Public Timeline
    
#----------------------------------------------------------------------------------------------------#
status = public_tweets[0]

#convert to string
json_str = json.dumps(status._json)

#deserialise string into python object
parsed = json.loads(json_str)

#pretty print
print(json.dumps(parsed, indent=4, sort_keys=True))

#----------------------------------------------------------------------------------------------------#
# Out:
# API.HOME_TIMELINE (OK):
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Tue Oct 22 01:02:04 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1186447597096992768",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/ju9Gqo3rna"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 18957805,
#                 "id_str": "18957805",
#                 "indices": [
#                     43,
#                     59
#                 ],
#                 "name": "Internet Archive",
#                 "screen_name": "internetarchive"
#             }
#         ]
#     },
#     "favorite_count": 9,
#     "favorited": false,
# ...
